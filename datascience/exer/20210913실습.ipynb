# %%
"""
print() Function
"""

print("Hello world")
print(100)
pi = 3.141592
print(pi)

introduce = "My name is "
name = "Jang Dong Min"

print(introduce + name + " " + "and i'm sleepy.")
# Out:
# Hello world
# 100
# 3.141592
# My name is Jang Dong Min and i'm sleepy.

# %%
"""
Variables
"""

user_name = " Jang Dong Min "
user_id = 201728039
user_name = 'njj05052@hs.ac.kr'
is_student = True
my_vision = 1.5

# %%
"""
Variable: Assignment
"""

x = 1
print('x = ', x)
print("Address of x: ", id(x))

x = 2
print('x = ', x)
print("Address of x: ", id(x))
# Out:
# x =  1
# Address of x:  140733566297904
# x =  2
# Address of x:  140733566297936

# %%
"""
Data types: Integers
"""

computer = 5
broken_dish = -1
moniter = 2

# %%
"""
Data types: Real Numbers
"""

pi = 3.141592
kimchi_premium = 1.11
krw_jpn_exchange = 1067.02

# %%
"""
Data Types: String
"""

favorite_juice = " lemonade "
favorite_game = " league of legends "
favorite_celebrity = " Park hyo shin "

favorites = favorite_juice + favorite_game + favorite_celebrity
print(favorites)
# Out:
#  lemonade  league of legends  Park hyo shin
